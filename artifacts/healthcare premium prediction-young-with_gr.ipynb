# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel("premiums_young_with_gr.xlsx")
df.head(3)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   18    Male  Northeast      Unmarried                     0   Overweight
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 2   21  Female  Southeast      Unmarried                     0       Normal
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0        Regular     Self-Employed        > 40L            99
# 1     No Smoking        Freelancer         <10L             3
# 2        Regular          Salaried        > 40L            97
#
#        Medical History Insurance_Plan  Annual_Premium_Amount  Genetical_Risk
# 0  High blood pressure         Silver                  13365               4
# 1           No Disease         Silver                  11050               3
# 2           No Disease         Silver                  11857               4

# %%
df.shape
# Out:
# (20096, 14)

# %%
df.columns = df.columns.str.replace(" ","_").str.lower()
df.head(3)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   18    Male  Northeast      Unmarried                     0   Overweight
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 2   21  Female  Southeast      Unmarried                     0       Normal
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0        Regular     Self-Employed        > 40L            99
# 1     No Smoking        Freelancer         <10L             3
# 2        Regular          Salaried        > 40L            97
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk
# 0  High blood pressure         Silver                  13365               4
# 1           No Disease         Silver                  11050               3
# 2           No Disease         Silver                  11857               4

# %% [markdown]
# ### Handle na values

# %%
df.isna().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           2
# employment_status        1
# income_level             4
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# genetical_risk           0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           0
# employment_status        0
# income_level             0
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# genetical_risk           0
# dtype: int64

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  20090.000000          20090.000000  20090.000000
# mean      21.494375              0.718019     22.510851
# std        2.294052              0.940713     23.420493
# min       18.000000             -3.000000      1.000000
# 25%       19.000000              0.000000      6.000000
# 50%       22.000000              0.000000     16.000000
# 75%       23.000000              1.000000     31.000000
# max       25.000000              3.000000    790.000000
#
#        annual_premium_amount  genetical_risk
# count           20090.000000    20090.000000
# mean             8142.096267        2.503932
# std              2749.906347        1.710203
# min              3501.000000        0.000000
# 25%              6022.250000        1.000000
# 50%              7939.000000        3.000000
# 75%              9561.000000        4.000000
# max             18186.000000        5.000000

# %%
df[df["number_of_dependants"] < 0].shape
# Out:
# (22, 14)

# %%
df["number_of_dependants"]=abs(df["number_of_dependants"])
df["number_of_dependants"].describe()
# Out:
# count    20090.000000
# mean         0.722598
# std          0.937200
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          3.000000
# Name: number_of_dependants, dtype: float64

# %%
numerical_columns=df.select_dtypes(['float64','int64']).columns
for col in numerical_columns:
  sns.boxplot(x= df[col])
  plt.show()

# %%
df[df.age>100]['age'].unique()
# Out:
# array([], dtype=int64)

# %%
df1 = df[df.age<=100].copy()

# %%
df1.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  20090.000000          20090.000000  20090.000000
# mean      21.494375              0.722598     22.510851
# std        2.294052              0.937200     23.420493
# min       18.000000              0.000000      1.000000
# 25%       19.000000              0.000000      6.000000
# 50%       22.000000              0.000000     16.000000
# 75%       23.000000              1.000000     31.000000
# max       25.000000              3.000000    790.000000
#
#        annual_premium_amount  genetical_risk
# count           20090.000000    20090.000000
# mean             8142.096267        2.503932
# std              2749.906347        1.710203
# min              3501.000000        0.000000
# 25%              6022.250000        1.000000
# 50%              7939.000000        3.000000
# 75%              9561.000000        4.000000
# max             18186.000000        5.000000

# %%
sns.histplot(df1["age"],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df1.income_lakhs)
# Out:
# <Axes: xlabel='income_lakhs', ylabel='Count'>

# %%
df1.income_lakhs.quantile([0.25,0.75])
# Out:
# 0.25     6.0
# 0.75    31.0
# Name: income_lakhs, dtype: float64

# %%
for col in numerical_columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# age: 0 outliers
# number_of_dependants: 1526 outliers
# income_lakhs: 1295 outliers
# annual_premium_amount: 430 outliers
# genetical_risk: 0 outliers

# %%
quantile_thersold=df1.income_lakhs.quantile(0.99)
quantile_thersold
# Out:
# 95.0

# %%
df2=df1[df1.income_lakhs<=quantile_thersold].copy()
df2
# Out:
#        age  gender     region marital_status  number_of_dependants  \
# 1       22  Female  Northwest      Unmarried                     0
# 3       25    Male  Southeast      Unmarried                     0
# 4       20    Male  Southeast      Unmarried                     2
# 5       22  Female  Southwest      Unmarried                     0
# 6       19    Male  Southwest      Unmarried                     0
# ...    ...     ...        ...            ...                   ...
# 20091   18  Female  Southeast      Unmarried                     0
# 20092   23  Female  Northwest      Unmarried                     0
# 20093   24  Female  Northwest      Unmarried                     0
# 20094   21    Male  Northwest      Unmarried                     0
# 20095   18    Male  Northwest      Unmarried                     2
#
#       bmi_category smoking_status employment_status income_level  \
# 1      Underweight     No Smoking        Freelancer         <10L
# 3           Normal     No Smoking        Freelancer    10L - 25L
# 4       Overweight     No Smoking        Freelancer    10L - 25L
# 5      Underweight        Regular        Freelancer    25L - 40L
# 6           Normal     No Smoking        Freelancer         <10L
# ...            ...            ...               ...          ...
# 20091  Underweight     No Smoking        Freelancer        > 40L
# 20092      Obesity     Occasional        Freelancer        > 40L
# 20093  Underweight     No Smoking     Self-Employed    25L - 40L
# 20094       Normal        Regular        Freelancer    25L - 40L
# 20095       Normal     No Smoking          Salaried    10L - 25L
#
#        income_lakhs      medical_history insurance_plan  \
# 1                 3           No Disease         Silver
# 3                15           No Disease         Bronze
# 4                14           No Disease         Bronze
# 5                30  High blood pressure           Gold
# 6                 8           No Disease         Bronze
# ...             ...                  ...            ...
# 20091            91           No Disease           Gold
# 20092            57             Diabetes           Gold
# 20093            35           No Disease         Bronze
# 20094            32           No Disease         Bronze
# 20095            20           No Disease         Bronze
#
#        annual_premium_amount  genetical_risk
# 1                      11050               3
# 3                       5684               2
# 4                       5712               1
# 5                      15473               3
# 6                       4097               0
# ...                      ...             ...
# 20091                  11603               1
# 20092                  14498               2
# 20093                   9111               5
# 20094                   8564               4
# 20095                   9490               5
#
# [19891 rows x 14 columns]

# %%
df2.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  19891.000000          19891.000000  19891.000000
# mean      21.494947              0.722538     21.649641
# std        2.293939              0.937614     20.503047
# min       18.000000              0.000000      1.000000
# 25%       19.000000              0.000000      6.000000
# 50%       22.000000              0.000000     16.000000
# 75%       23.000000              1.000000     31.000000
# max       25.000000              3.000000     95.000000
#
#        annual_premium_amount  genetical_risk
# count           19891.000000    19891.000000
# mean             8112.725705        2.501835
# std              2738.395100        1.710358
# min              3501.000000        0.000000
# 25%              5999.000000        1.000000
# 50%              7914.000000        3.000000
# 75%              9524.500000        4.000000
# max             18186.000000        5.000000

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))  # Adjust the size to ensure plots are not squeezed

for i, column in enumerate( numerical_columns):
    # Locating the correct subplot using integer division and modulus
    ax = axs[i // 3, i % 3]  # Row index is i//3, column index is i%3
    sns.histplot(df2[column], kde=True, ax=ax)
    ax.set_title(column)

# If the last subplot axis is unused, you can turn it off
if len( numerical_columns) % 3 != 0:
    for j in range(len( numerical_columns), 4):  # This will disable any unused subplots
        axs.flat[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
sns.histplot(df2["income_lakhs"],kde=True)
# Out:
# <Axes: xlabel='income_lakhs', ylabel='Count'>

# %%
for col in numerical_columns:
    sns.histplot(df2[col],kde=True)
    plt.show()

# %%
sns.scatterplot(df2,x="age",y="annual_premium_amount")
# Out:
# <Axes: xlabel='age', ylabel='annual_premium_amount'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_features = ['age', 'annual_premium_amount', 'income_lakhs']

for col in numerical_features:
    plt.figure(figsize=(6, 4))
    sns.scatterplot(x=df2[col], y=df2['annual_premium_amount'])
    plt.title(f'{col} vs annual_premium_amount')
    plt.xlabel(col)
    plt.ylabel('annual_premium_amount')
    plt.show()

# %%
df2
# Out:
#        age  gender     region marital_status  number_of_dependants  \
# 1       22  Female  Northwest      Unmarried                     0
# 3       25    Male  Southeast      Unmarried                     0
# 4       20    Male  Southeast      Unmarried                     2
# 5       22  Female  Southwest      Unmarried                     0
# 6       19    Male  Southwest      Unmarried                     0
# ...    ...     ...        ...            ...                   ...
# 20091   18  Female  Southeast      Unmarried                     0
# 20092   23  Female  Northwest      Unmarried                     0
# 20093   24  Female  Northwest      Unmarried                     0
# 20094   21    Male  Northwest      Unmarried                     0
# 20095   18    Male  Northwest      Unmarried                     2
#
#       bmi_category smoking_status employment_status income_level  \
# 1      Underweight     No Smoking        Freelancer         <10L
# 3           Normal     No Smoking        Freelancer    10L - 25L
# 4       Overweight     No Smoking        Freelancer    10L - 25L
# 5      Underweight        Regular        Freelancer    25L - 40L
# 6           Normal     No Smoking        Freelancer         <10L
# ...            ...            ...               ...          ...
# 20091  Underweight     No Smoking        Freelancer        > 40L
# 20092      Obesity     Occasional        Freelancer        > 40L
# 20093  Underweight     No Smoking     Self-Employed    25L - 40L
# 20094       Normal        Regular        Freelancer    25L - 40L
# 20095       Normal     No Smoking          Salaried    10L - 25L
#
#        income_lakhs      medical_history insurance_plan  \
# 1                 3           No Disease         Silver
# 3                15           No Disease         Bronze
# 4                14           No Disease         Bronze
# 5                30  High blood pressure           Gold
# 6                 8           No Disease         Bronze
# ...             ...                  ...            ...
# 20091            91           No Disease           Gold
# 20092            57             Diabetes           Gold
# 20093            35           No Disease         Bronze
# 20094            32           No Disease         Bronze
# 20095            20           No Disease         Bronze
#
#        annual_premium_amount  genetical_risk
# 1                      11050               3
# 3                       5684               2
# 4                       5712               1
# 5                      15473               3
# 6                       4097               0
# ...                      ...             ...
# 20091                  11603               1
# 20092                  14498               2
# 20093                   9111               5
# 20094                   8564               4
# 20095                   9490               5
#
# [19891 rows x 14 columns]

# %%
categorical_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status', 'income_level', 'medical_history', 'insurance_plan']
for col in categorical_cols:
    print(col, ":", df2[col].unique())
# Out:
# gender : ['Female' 'Male']
# region : ['Northwest' 'Southeast' 'Southwest' 'Northeast']
# marital_status : ['Unmarried' 'Married']
# bmi_category : ['Underweight' 'Normal' 'Overweight' 'Obesity']
# smoking_status : ['No Smoking' 'Regular' 'Occasional' 'Smoking=0' 'Does Not Smoke'
#  'Not Smoking']
# employment_status : ['Freelancer' 'Salaried' 'Self-Employed']
# income_level : ['<10L' '10L - 25L' '25L - 40L' '> 40L']
# medical_history : ['No Disease' 'High blood pressure' 'Diabetes & High blood pressure'
#  'Diabetes & Heart disease' 'Diabetes' 'Diabetes & Thyroid'
#  'Heart disease' 'Thyroid' 'High blood pressure & Heart disease']
# insurance_plan : ['Silver' 'Bronze' 'Gold']

# %%
df2['smoking_status'] = df2['smoking_status'].replace({
    'Not Smoking': 'No Smoking',
    'Does Not Smoke': 'No Smoking',
    'Smoking=0': 'No Smoking'
})

# %%
df2.head(3)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 3   25    Male  Southeast      Unmarried                     0       Normal
# 4   20    Male  Southeast      Unmarried                     2   Overweight
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 1     No Smoking        Freelancer         <10L             3      No Disease
# 3     No Smoking        Freelancer    10L - 25L            15      No Disease
# 4     No Smoking        Freelancer    10L - 25L            14      No Disease
#
#   insurance_plan  annual_premium_amount  genetical_risk
# 1         Silver                  11050               3
# 3         Bronze                   5684               2
# 4         Bronze                   5712               1

# %%
df2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 3   25    Male  Southeast      Unmarried                     0       Normal
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 1     No Smoking        Freelancer         <10L             3      No Disease
# 3     No Smoking        Freelancer    10L - 25L            15      No Disease
#
#   insurance_plan  annual_premium_amount  genetical_risk
# 1         Silver                  11050               3
# 3         Bronze                   5684               2

# %%
pct_count = df2['gender'].value_counts(normalize=True)*100
pct_count
# Out:
# gender
# Male      55.024886
# Female    44.975114
# Name: proportion, dtype: float64

# %%
sns.barplot(x=pct_count.index, y=pct_count.values)
# Out:
# <Axes: xlabel='gender'>

# %%
crosstab=pd.crosstab(df2["income_level"],df2["insurance_plan"])
print(crosstab)

crosstab.plot(kind="bar")
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L         4508   326     828
# 25L - 40L         3382   209     608
# <10L              6172   404    1145
# > 40L              109   331    1869
# <Axes: xlabel='income_level'>

# %%
sns.heatmap(crosstab,annot=True,fmt="d")
# Out:
# <Axes: xlabel='insurance_plan', ylabel='income_level'>

# %%
df2.medical_history.unique()
# Out:
# array(['No Disease', 'High blood pressure',
#        'Diabetes & High blood pressure', 'Diabetes & Heart disease',
#        'Diabetes', 'Diabetes & Thyroid', 'Heart disease', 'Thyroid',
#        'High blood pressure & Heart disease'], dtype=object)

# %%
risk_scores = {
    "diabetes": 6,
    "heart disease": 8,
    "high blood pressure": 6,
    "thyroid": 5,
    "no disease": 0,
    "none": 0
}

df2[['disease1', 'disease2']] = (
    df2['medical_history']
    .str.split(" & ", expand=True)
    .apply(lambda x: x.str.lower().str.strip())
)

df2['disease1'] = df2['disease1'].fillna('none')
df2['disease2'] = df2['disease2'].fillna('none')

df2['total_risk_score'] = 0

for disease in ['disease1', 'disease2']:
    df2['total_risk_score'] += df2[disease].map(risk_scores).fillna(0)

max_score = df2['total_risk_score'].max()
min_score = df2['total_risk_score'].min()

df2['normalized_risk_score'] = (
    (df2['total_risk_score'] - min_score)
    / (max_score - min_score)
)

df2.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 1   22  Female  Northwest      Unmarried                     0  Underweight
# 3   25    Male  Southeast      Unmarried                     0       Normal
# 4   20    Male  Southeast      Unmarried                     2   Overweight
# 5   22  Female  Southwest      Unmarried                     0  Underweight
# 6   19    Male  Southwest      Unmarried                     0       Normal
#
#   smoking_status employment_status income_level  income_lakhs  \
# 1     No Smoking        Freelancer         <10L             3
# 3     No Smoking        Freelancer    10L - 25L            15
# 4     No Smoking        Freelancer    10L - 25L            14
# 5        Regular        Freelancer    25L - 40L            30
# 6     No Smoking        Freelancer         <10L             8
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk  \
# 1           No Disease         Silver                  11050               3
# 3           No Disease         Bronze                   5684               2
# 4           No Disease         Bronze                   5712               1
# 5  High blood pressure           Gold                  15473               3
# 6           No Disease         Bronze                   4097               0
#
#               disease1 disease2  total_risk_score  normalized_risk_score
# 1           no disease     none                 0               0.000000
# 3           no disease     none                 0               0.000000
# 4           no disease     none                 0               0.000000
# 5  high blood pressure     none                 6               0.428571
# 6           no disease     none                 0               0.000000

# %%
df2.insurance_plan.unique()
# Out:
# array(['Silver', 'Bronze', 'Gold'], dtype=object)

# %%
import pandas as pd
df2['insurance_plan'] = df2['insurance_plan'].map({'Bronze': 1, 'Silver': 2, 'Gold': 3})

# %%
df2.income_level.unique()
# Out:
# array(['<10L', '10L - 25L', '25L - 40L', '> 40L'], dtype=object)

# %%
df2['income_level'] = df2['income_level'].map({'<10L':1, '10L - 25L': 2, '25L - 40L':3, '> 40L':4})

# %%
df2
# Out:
#        age  gender     region marital_status  number_of_dependants  \
# 1       22  Female  Northwest      Unmarried                     0
# 3       25    Male  Southeast      Unmarried                     0
# 4       20    Male  Southeast      Unmarried                     2
# 5       22  Female  Southwest      Unmarried                     0
# 6       19    Male  Southwest      Unmarried                     0
# ...    ...     ...        ...            ...                   ...
# 20091   18  Female  Southeast      Unmarried                     0
# 20092   23  Female  Northwest      Unmarried                     0
# 20093   24  Female  Northwest      Unmarried                     0
# 20094   21    Male  Northwest      Unmarried                     0
# 20095   18    Male  Northwest      Unmarried                     2
#
#       bmi_category smoking_status employment_status  income_level  \
# 1      Underweight     No Smoking        Freelancer             1
# 3           Normal     No Smoking        Freelancer             2
# 4       Overweight     No Smoking        Freelancer             2
# 5      Underweight        Regular        Freelancer             3
# 6           Normal     No Smoking        Freelancer             1
# ...            ...            ...               ...           ...
# 20091  Underweight     No Smoking        Freelancer             4
# 20092      Obesity     Occasional        Freelancer             4
# 20093  Underweight     No Smoking     Self-Employed             3
# 20094       Normal        Regular        Freelancer             3
# 20095       Normal     No Smoking          Salaried             2
#
#        income_lakhs      medical_history  insurance_plan  \
# 1                 3           No Disease               2
# 3                15           No Disease               1
# 4                14           No Disease               1
# 5                30  High blood pressure               3
# 6                 8           No Disease               1
# ...             ...                  ...             ...
# 20091            91           No Disease               3
# 20092            57             Diabetes               3
# 20093            35           No Disease               1
# 20094            32           No Disease               1
# 20095            20           No Disease               1
#
#        annual_premium_amount  genetical_risk             disease1 disease2  \
# 1                      11050               3           no disease     none
# 3                       5684               2           no disease     none
# 4                       5712               1           no disease     none
# 5                      15473               3  high blood pressure     none
# 6                       4097               0           no disease     none
# ...                      ...             ...                  ...      ...
# 20091                  11603               1           no disease     none
# 20092                  14498               2             diabetes     none
# 20093                   9111               5           no disease     none
# 20094                   8564               4           no disease     none
# 20095                   9490               5           no disease     none
#
#        total_risk_score  normalized_risk_score
# 1                     0               0.000000
# 3                     0               0.000000
# 4                     0               0.000000
# 5                     6               0.428571
# 6                     0               0.000000
# ...                 ...                    ...
# 20091                 0               0.000000
# 20092                 6               0.428571
# 20093                 0               0.000000
# 20094                 0               0.000000
# 20095                 0               0.000000
#
# [19891 rows x 18 columns]

# %%
nominal_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status']
df3 = pd.get_dummies(df2, columns=nominal_cols, drop_first=True, dtype=int)
df3.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs medical_history  \
# 1   22                     0             1             3      No Disease
# 3   25                     0             2            15      No Disease
# 4   20                     2             2            14      No Disease
#
#    insurance_plan  annual_premium_amount  genetical_risk    disease1 disease2  \
# 1               2                  11050               3  no disease     none
# 3               1                   5684               2  no disease     none
# 4               1                   5712               1  no disease     none
#
#    ...  region_Southeast  region_Southwest  marital_status_Unmarried  \
# 1  ...                 0                 0                         1
# 3  ...                 1                 0                         1
# 4  ...                 1                 0                         1
#
#    bmi_category_Obesity  bmi_category_Overweight  bmi_category_Underweight  \
# 1                     0                        0                         1
# 3                     0                        0                         0
# 4                     0                        1                         0
#
#    smoking_status_Occasional  smoking_status_Regular  \
# 1                          0                       0
# 3                          0                       0
# 4                          0                       0
#
#    employment_status_Salaried  employment_status_Self-Employed
# 1                           0                                0
# 3                           0                                0
# 4                           0                                0
#
# [3 rows x 24 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19891 entries, 1 to 20095
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              19891 non-null  int64
#  1   number_of_dependants             19891 non-null  int64
#  2   income_level                     19891 non-null  int64
#  3   income_lakhs                     19891 non-null  int64
#  4   medical_history                  19891 non-null  object
#  5   insurance_plan                   19891 non-null  int64
#  6   annual_premium_amount            19891 non-null  int64
#  7   genetical_risk                   19891 non-null  int64
#  8   disease1                         19891 non-null  object
#  9   disease2                         19891 non-null  object
#  10  total_risk_score                 19891 non-null  int64
#  11  normalized_risk_score            19891 non-null  float64
#  12  gender_Male                      19891 non-null  int32
#  13  region_Northwest                 19891 non-null  int32
#  14  region_Southeast                 19891 non-null  int32
#  15  region_Southwest                 19891 non-null  int32
#  16  marital_status_Unmarried         19891 non-null  int32
#  17  bmi_category_Obesity             19891 non-null  int32
#  18  bmi_category_Overweight          19891 non-null  int32
#  19  bmi_category_Underweight         19891 non-null  int32
#  20  smoking_status_Occasional        19891 non-null  int32
#  21  smoking_status_Regular           19891 non-null  int32
#  22  employment_status_Salaried       19891 non-null  int32
#  23  employment_status_Self-Employed  19891 non-null  int32
# dtypes: float64(1), int32(12), int64(8), object(3)
# memory usage: 2.9+ MB

# %%
df4 = df3.drop(['medical_history','disease1', 'disease2', 'total_risk_score'], axis=1)
df4.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 1   22                     0             1             3               2
# 3   25                     0             2            15               1
# 4   20                     2             2            14               1
#
#    annual_premium_amount  genetical_risk  normalized_risk_score  gender_Male  \
# 1                  11050               3                    0.0            0
# 3                   5684               2                    0.0            1
# 4                   5712               1                    0.0            1
#
#    region_Northwest  region_Southeast  region_Southwest  \
# 1                 1                 0                 0
# 3                 0                 1                 0
# 4                 0                 1                 0
#
#    marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# 1                         1                     0                        0
# 3                         1                     0                        0
# 4                         1                     0                        1
#
#    bmi_category_Underweight  smoking_status_Occasional  \
# 1                         1                          0
# 3                         0                          0
# 4                         0                          0
#
#    smoking_status_Regular  employment_status_Salaried  \
# 1                       0                           0
# 3                       0                           0
# 4                       0                           0
#
#    employment_status_Self-Employed
# 1                                0
# 3                                0
# 4                                0

# %%
df4.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_level', 'income_lakhs',
#        'insurance_plan', 'annual_premium_amount', 'genetical_risk',
#        'normalized_risk_score', 'gender_Male', 'region_Northwest',
#        'region_Southeast', 'region_Southwest', 'marital_status_Unmarried',
#        'bmi_category_Obesity', 'bmi_category_Overweight',
#        'bmi_category_Underweight', 'smoking_status_Occasional',
#        'smoking_status_Regular', 'employment_status_Salaried',
#        'employment_status_Self-Employed'],
#       dtype='object')

# %%
cm = df4.corr()

plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
X = df4.drop('annual_premium_amount', axis='columns')
y = df4['annual_premium_amount']

from sklearn.preprocessing import MinMaxScaler

cols_to_scale = ['age','number_of_dependants', 'income_level',  'income_lakhs', 'insurance_plan']
scaler = MinMaxScaler()

X[cols_to_scale] = scaler.fit_transform(X[cols_to_scale])
X.describe()
# Out:
#                 age  number_of_dependants  income_level  income_lakhs  \
# count  19891.000000          19891.000000  19891.000000  19891.000000
# mean       0.499278              0.240846      0.351700      0.219677
# std        0.327706              0.312538      0.343287      0.218118
# min        0.000000              0.000000      0.000000      0.000000
# 25%        0.142857              0.000000      0.000000      0.053191
# 50%        0.571429              0.000000      0.333333      0.159574
# 75%        0.714286              0.333333      0.666667      0.319149
# max        1.000000              1.000000      1.000000      1.000000
#
#        insurance_plan  genetical_risk  normalized_risk_score   gender_Male  \
# count    19891.000000    19891.000000           19891.000000  19891.000000
# mean         0.175708        2.501835               0.092113      0.550249
# std          0.298176        1.710358               0.230085      0.497481
# min          0.000000        0.000000               0.000000      0.000000
# 25%          0.000000        1.000000               0.000000      0.000000
# 50%          0.000000        3.000000               0.000000      1.000000
# 75%          0.500000        4.000000               0.000000      1.000000
# max          1.000000        5.000000               1.000000      1.000000
#
#        region_Northwest  region_Southeast  region_Southwest  \
# count      19891.000000      19891.000000      19891.000000
# mean           0.201247          0.347242          0.304208
# std            0.400942          0.476106          0.460083
# min            0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000
# 50%            0.000000          0.000000          0.000000
# 75%            0.000000          1.000000          1.000000
# max            1.000000          1.000000          1.000000
#
#        marital_status_Unmarried  bmi_category_Obesity  \
# count              19891.000000          19891.000000
# mean                   0.899603              0.063345
# std                    0.300536              0.243589
# min                    0.000000              0.000000
# 25%                    1.000000              0.000000
# 50%                    1.000000              0.000000
# 75%                    1.000000              0.000000
# max                    1.000000              1.000000
#
#        bmi_category_Overweight  bmi_category_Underweight  \
# count             19891.000000              19891.000000
# mean                  0.136494                  0.222261
# std                   0.343321                  0.415776
# min                   0.000000                  0.000000
# 25%                   0.000000                  0.000000
# 50%                   0.000000                  0.000000
# 75%                   0.000000                  0.000000
# max                   1.000000                  1.000000
#
#        smoking_status_Occasional  smoking_status_Regular  \
# count               19891.000000            19891.000000
# mean                    0.086170                0.223971
# std                     0.280621                0.416913
# min                     0.000000                0.000000
# 25%                     0.000000                0.000000
# 50%                     0.000000                0.000000
# 75%                     0.000000                0.000000
# max                     1.000000                1.000000
#
#        employment_status_Salaried  employment_status_Self-Employed
# count                19891.000000                     19891.000000
# mean                     0.350209                         0.149615
# std                      0.477047                         0.356703
# min                      0.000000                         0.000000
# 25%                      0.000000                         0.000000
# 50%                      0.000000                         0.000000
# 75%                      1.000000                         0.000000
# max                      1.000000                         1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X)
# Out:
#                              Column        VIF
# 0                               age   3.155272
# 1              number_of_dependants   1.931595
# 2                      income_level  12.889845
# 3                      income_lakhs  13.108623
# 4                    insurance_plan   1.555590
# 5                    genetical_risk   2.975455
# 6             normalized_risk_score   1.154585
# 7                       gender_Male   2.312736
# 8                  region_Northwest   2.153199
# 9                  region_Southeast   2.992036
# 10                 region_Southwest   2.740791
# 11         marital_status_Unmarried   8.003806
# 12             bmi_category_Obesity   1.109530
# 13          bmi_category_Overweight   1.232623
# 14         bmi_category_Underweight   1.368481
# 15        smoking_status_Occasional   1.132838
# 16           smoking_status_Regular   1.385560
# 17       employment_status_Salaried   1.674818
# 18  employment_status_Self-Employed   1.294795

# %%
calculate_vif(X.drop('income_level', axis="columns"))
# Out:
#                              Column       VIF
# 0                               age  3.154177
# 1              number_of_dependants  1.929986
# 2                      income_lakhs  2.304155
# 3                    insurance_plan  1.549707
# 4                    genetical_risk  2.975455
# 5             normalized_risk_score  1.154554
# 6                       gender_Male  2.301809
# 7                  region_Northwest  2.152622
# 8                  region_Southeast  2.991512
# 9                  region_Southwest  2.740499
# 10         marital_status_Unmarried  7.989344
# 11             bmi_category_Obesity  1.109513
# 12          bmi_category_Overweight  1.232428
# 13         bmi_category_Underweight  1.368444
# 14        smoking_status_Occasional  1.132832
# 15           smoking_status_Regular  1.385383
# 16       employment_status_Salaried  1.669046
# 17  employment_status_Self-Employed  1.292216

# %%
X_reduced = X.drop('income_level', axis="columns")

# %%
calculate_vif(X.drop('income_level', axis="columns"))
# Out:
#                              Column       VIF
# 0                               age  3.154177
# 1              number_of_dependants  1.929986
# 2                      income_lakhs  2.304155
# 3                    insurance_plan  1.549707
# 4                    genetical_risk  2.975455
# 5             normalized_risk_score  1.154554
# 6                       gender_Male  2.301809
# 7                  region_Northwest  2.152622
# 8                  region_Southeast  2.991512
# 9                  region_Southwest  2.740499
# 10         marital_status_Unmarried  7.989344
# 11             bmi_category_Obesity  1.109513
# 12          bmi_category_Overweight  1.232428
# 13         bmi_category_Underweight  1.368444
# 14        smoking_status_Occasional  1.132832
# 15           smoking_status_Regular  1.385383
# 16       employment_status_Salaried  1.669046
# 17  employment_status_Self-Employed  1.292216

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.30, random_state=10)

# shape of the X_train, X_test, y_train, y_test features
print("x train: ",X_train.shape)
print("x test: ",X_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# x train:  (13923, 18)
# x test:  (5968, 18)
# y train:  (13923,)
# y test:  (5968,)

# %%
from sklearn.linear_model import LinearRegression
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
test_score = model_lr.score(X_test, y_test)
train_score = model_lr.score(X_train, y_train)
train_score, test_score
# Out:
# (0.9885435079478863, 0.9878137118901228)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split

y_pred = model_lr.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("Linear Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Linear Regression ==> MSE:  88911.46803951959 RMSE:  298.1802609823789

# %%
feature_importance = model_lr.coef_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in Linear Regression')
plt.show()

# %%
model_rg = Ridge(alpha=1)
model_rg.fit(X_train, y_train)
test_score = model_rg.score(X_test, y_test)
train_score = model_rg.score(X_train, y_train)
train_score, test_score
# Out:
# (0.9885430530174625, 0.9878091576436574)

# %%
y_pred = model_rg.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("Ridge Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Ridge Regression ==> MSE:  88944.6959375803 RMSE:  298.23597358062005

# %%
from xgboost import XGBRegressor

model_xgb = XGBRegressor(n_estimators=20, max_depth=3)
model_xgb.fit(X_train, y_train)
model_xgb.score(X_test, y_test)
# Out:
# 0.9865981340408325

# %%
model_xgb = XGBRegressor()
param_grid = {
    'n_estimators': [20, 40, 50],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
}
random_search = RandomizedSearchCV(model_xgb, param_grid, n_iter=10, cv=3, scoring='r2', random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)
random_search.best_score_
# Out:
# 0.9881140987078348

# %%
random_search.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.1}

# %%
best_model = random_search.best_estimator_

# %%
feature_importance = best_model.feature_importances_

# Create a DataFrame for easier handling
coef_df = pd.DataFrame(feature_importance, index=X_train.columns, columns=['Coefficients'])

# Sort the coefficients for better visualization
coef_df = coef_df.sort_values(by='Coefficients', ascending=True)

# Plotting
plt.figure(figsize=(8, 4))
plt.barh(coef_df.index, coef_df['Coefficients'], color='steelblue')
plt.xlabel('Coefficient Value')
plt.title('Feature Importance in XGBoost')
plt.show()

# %%
y_pred = best_model.predict(X_test)

residuals = y_pred - y_test
residuals_pct = (residuals / y_test) * 100

results_df = pd.DataFrame({
    'actual': y_test, 
    'predicted': y_pred, 
    'diff': residuals, 
    'diff_pct': residuals_pct
})
results_df.head()
# Out:
#        actual     predicted        diff  diff_pct
# 1177     3891   4096.403320  205.403320  5.278934
# 2886     8696   9017.023438  321.023438  3.691622
# 14175    7751   7390.336914 -360.663086 -4.653117
# 18213   11833  11827.054688   -5.945312 -0.050243
# 1166     7391   7586.907227  195.907227  2.650619

# %%
sns.histplot(results_df['diff_pct'], kde=True)
plt.title('Distribution of Residuals')
plt.xlabel('Diff PCT')
plt.ylabel('Frequency')
plt.show()

# %%
df.shape
# Out:
# (20090, 14)

# %%
extreme_error_threshold = 10  # You can adjust this threshold based on your domain knowledge or requirements
extreme_results_df = results_df[np.abs(results_df['diff_pct']) > extreme_error_threshold]
extreme_results_df.head()
# Out:
#        actual    predicted        diff   diff_pct
# 10855    4502  5071.009277  569.009277  12.639033
# 19951    3751  4275.331055  524.331055  13.978434
# 6106     4569  5071.009277  502.009277  10.987290
# 18329    4615  5119.686035  504.686035  10.935775
# 15055    3684  4133.910645  449.910645  12.212558

# %%
extreme_results_df.shape
# Out:
# (143, 4)

# %%
extreme_errors_pct = extreme_results_df.shape[0]*100/X_test.shape[0]
extreme_errors_pct
# Out:
# 2.3961126005361932

# %%
extreme_results_df[abs(extreme_results_df.diff_pct)>50].sort_values("diff_pct",ascending=False)
# Out:
# Empty DataFrame
# Columns: [actual, predicted, diff, diff_pct]
# Index: []

# %%
extreme_errors_df = X_test.loc[extreme_results_df.index]
extreme_errors_df.head(2)
# Out:
#             age  number_of_dependants  income_lakhs  insurance_plan  \
# 10855  0.571429                   0.0      0.042553             0.0
# 19951  0.571429                   0.0      0.031915             0.0
#
#        genetical_risk  normalized_risk_score  gender_Male  region_Northwest  \
# 10855               1                    0.0            0                 0
# 19951               0                    0.0            1                 0
#
#        region_Southeast  region_Southwest  marital_status_Unmarried  \
# 10855                 1                 0                         1
# 19951                 0                 0                         1
#
#        bmi_category_Obesity  bmi_category_Overweight  \
# 10855                     0                        0
# 19951                     0                        0
#
#        bmi_category_Underweight  smoking_status_Occasional  \
# 10855                         0                          0
# 19951                         0                          1
#
#        smoking_status_Regular  employment_status_Salaried  \
# 10855                       0                           0
# 19951                       0                           0
#
#        employment_status_Self-Employed
# 10855                                0
# 19951                                0

# %%
for feature in X_test.columns:
    plt.figure(figsize=(10, 4))
    sns.histplot(extreme_errors_df[feature], color='red', label='Extreme Errors', kde=True)
    sns.histplot(X_test[feature], color='blue', label='Overall', alpha=0.5, kde=True)
    plt.legend()
    plt.title(f'Distribution of {feature} for Extreme Errors vs Overall')
    plt.show()

# %%
extreme_errors_df['income_level']=-1

# %%
df_reversed = pd.DataFrame()
df_reversed[cols_to_scale] = scaler.inverse_transform(extreme_errors_df[cols_to_scale])
df_reversed.head()
# Out:
#     age  number_of_dependants  income_level  income_lakhs  insurance_plan
# 0  22.0                   0.0          -2.0           5.0             1.0
# 1  22.0                   0.0          -2.0           4.0             1.0
# 2  20.0                   0.0          -2.0           8.0             1.0
# 3  25.0                   0.0          -2.0           4.0             1.0
# 4  22.0                   1.0          -2.0          36.0             1.0

# %%
df_reversed.describe()
# Out:
#               age  number_of_dependants  income_level  income_lakhs  \
# count  143.000000            143.000000         143.0    143.000000
# mean    21.328671              0.720280          -2.0     16.391608
# std      2.088790              0.945006           0.0     14.002030
# min     18.000000              0.000000          -2.0      1.000000
# 25%     19.000000              0.000000          -2.0      6.000000
# 50%     21.000000              0.000000          -2.0     12.000000
# 75%     23.000000              1.000000          -2.0     25.500000
# max     25.000000              3.000000          -2.0     91.000000
#
#        insurance_plan
# count           143.0
# mean              1.0
# std               0.0
# min               1.0
# 25%               1.0
# 50%               1.0
# 75%               1.0
# max               1.0

# %%
sns.histplot(df_reversed.age)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\deval\anaconda3\lib\site-packages (1.4.2)Note: you may need to restart the kernel to use updated packages.

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# C:\Users\deval\OneDrive\Desktop\Deval

# %%
import os

os.mkdir("artifacts")
print("Folder created!")
# Out:
# Folder created!

# %%
from joblib import dump

dump(best_model, "artifacts/model_young.joblib")

scaler_with_cols = {
    "scaler": scaler,
    "cols_to_scale": cols_to_scale
}

dump(scaler_with_cols, "artifacts/scaler_young.joblib")

print("Saved Successfully!")
# Out:
# Saved Successfully!
